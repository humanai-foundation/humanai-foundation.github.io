# %% [markdown]
# # Library

# %%
import sys
sys.path.append('../../Util')
import PreProcessingUtils as ppu
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read Data

# %%
PATH = "../../Datasets/"

# %%
df = pd.read_csv(f"{PATH}RawData/threads.csv")
df
# Out:
#                id  site_id  board_id          creator  creator_id  label  \
# 0      1098607808     1019       258       randalthor         408    NaN
# 1      1208831554     1019        18        sickde666        7360    NaN
# 2      1731938282     1019        56     straightdave       13667    NaN
# 3      1161153828     1019        56   Krispykremelad        4853    NaN
# 4       929896129     1019        56       yungtiller        5524    NaN
# ...           ...      ...       ...              ...         ...    ...
# 75117   566787583     1019       441          fairfax       33131    NaN
# 75118   161231059     1019       441           Denode       41474    NaN
# 75119    26637282     1019       441           Denode       41474    NaN
# 75120   341142936     1019       441  DomesticProduct       42899    NaN
# 75121  1821634035     1019       441           Denode       41474    NaN
#
#                                                     name  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75122 entries, 0 to 75121
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             75122 non-null  int64
#  1   site_id        75122 non-null  int64
#  2   board_id       75122 non-null  int64
#  3   creator        74867 non-null  object
#  4   creator_id     75122 non-null  int64
#  5   label          0 non-null      float64
#  6   name           75122 non-null  object
#  7   url            75122 non-null  object
#  8   created_on     75122 non-null  object
#  9   last_post_on   0 non-null      float64
#  10  db_created_on  75122 non-null  object
#  11  db_updated_on  75122 non-null  object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 6.9+ MB

# %%
df.describe()
# Out:
#                  id  site_id      board_id    creator_id  label  last_post_on
# count  7.512200e+04  75122.0  75122.000000  75122.000000    0.0           0.0
# mean   1.075652e+09   1019.0     63.129749  11827.177005    NaN           NaN
# std    6.199184e+08      0.0     97.533545  12627.206364    NaN           NaN
# min    3.372500e+04   1019.0      1.000000     -1.000000    NaN           NaN
# 25%    5.369132e+08   1019.0     10.000000   1969.000000    NaN           NaN
# 50%    1.080713e+09   1019.0     18.000000   7214.000000    NaN           NaN
# 75%    1.610658e+09   1019.0     65.000000  16937.750000    NaN           NaN
# max    2.147418e+09   1019.0    446.000000  47346.000000    NaN           NaN

# %%
df.describe(include='object')
# Out:
#           creator                                               name  \
# count       74867                                              75122
# unique      24062                                              69833
# top     [deleted]  MEDICAL GRADE LIQUID KETAMINE AVAILABLE. USA a...
# freq          807                                                 54
#
#                                                       url  \
# count                                               75122
# unique                                              75122
# top     http://dreadditevelidot.onion/post/d0e38d2ba74...
# freq                                                    1
#
#                         created_on               db_created_on  \
# count                        75122                       75122
# unique                       75122                       75122
# top     2020-01-09 15:35:04.078374  2020-01-09 15:35:04.078374
# freq                             1                           1
#
# ...

# %%
df.nunique()
# Out:
# id               75122
# site_id              1
# board_id           382
# creator          24062
# creator_id       24428
# label                0
# name             69833
# url              75122
# created_on       75122
# last_post_on         0
# db_created_on    75122
# db_updated_on    75122
# dtype: int64

# %%
df.isnull().sum()
# Out:
# id                   0
# site_id              0
# board_id             0
# creator            255
# creator_id           0
# label            75122
# name                 0
# url                  0
# created_on           0
# last_post_on     75122
# db_created_on        0
# db_updated_on        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[(df['db_created_on'] == df['db_updated_on']) & (df['db_updated_on'] == df['created_on'])][['db_created_on', 'db_updated_on', 'created_on']]
# Out:
#                     db_created_on               db_updated_on  \
# 0      2020-01-09 15:35:04.078374  2020-01-09 15:35:04.078374
# 1       2020-01-08 14:32:21.56381   2020-01-08 14:32:21.56381
# 2      2019-08-07 23:48:54.215944  2019-08-07 23:48:54.215944
# 3      2019-08-07 23:48:57.902027  2019-08-07 23:48:57.902027
# 4      2019-08-07 23:49:01.210173  2019-08-07 23:49:01.210173
# ...                           ...                         ...
# 75117  2020-01-09 21:07:16.622158  2020-01-09 21:07:16.622158
# 75118   2020-01-09 21:07:18.79134   2020-01-09 21:07:18.79134
# 75119   2020-01-09 21:07:21.14179   2020-01-09 21:07:21.14179
# 75120   2020-01-09 21:07:23.72459   2020-01-09 21:07:23.72459
# 75121  2020-01-09 21:07:26.882408  2020-01-09 21:07:26.882408
#
#                        created_on
# 0      2020-01-09 15:35:04.078374
# 1       2020-01-08 14:32:21.56381
# 2      2019-08-07 23:48:54.215944
# 3      2019-08-07 23:48:57.902027
# 4      2019-08-07 23:49:01.210173
# ...

# %%
df.drop(columns=['site_id', 'label', 'last_post_on', 'db_created_on', 'db_updated_on'], inplace=True)

# %%
df.head()
# Out:
#            id  board_id         creator  creator_id  \
# 0  1098607808       258      randalthor         408
# 1  1208831554        18       sickde666        7360
# 2  1731938282        56    straightdave       13667
# 3  1161153828        56  Krispykremelad        4853
# 4   929896129        56      yungtiller        5524
#
#                                      name  \
# 0                             where 2 now
# 1                                   Login
# 2                      Withdrawals locked
# 3  No moderator on my dispute for 8 days?
# 4                                  No pin
#
#                                                  url  \
# 0  http://dreadditevelidot.onion/post/d0e38d2ba74...
# 1  http://dreadditevelidot.onion/post/6ada35da0b3...
# 2  http://dreadditevelidot.onion/post/17e952b5b6d...
# 3  http://dreadditevelidot.onion/post/9f2dad3183b...
# 4  http://dreadditevelidot.onion/post/5f2a5a75a93...
#
#                    created_on
# 0  2020-01-09 15:35:04.078374
# ...

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ## Url feature

# %%
ppu.preprocess_url(df, 'url')
# Out:
#                id  board_id          creator  creator_id  \
# 0      1098607808       258       randalthor         408
# 1      1208831554        18        sickde666        7360
# 2      1731938282        56     straightdave       13667
# 3      1161153828        56   Krispykremelad        4853
# 4       929896129        56       yungtiller        5524
# ...           ...       ...              ...         ...
# 75117   566787583       441          fairfax       33131
# 75118   161231059       441           Denode       41474
# 75119    26637282       441           Denode       41474
# 75120   341142936       441  DomesticProduct       42899
# 75121  1821634035       441           Denode       41474
#
#                                                     name               url  \
# 0                                            where 2 now  dreadditevelidot
# 1                                                  Login  dreadditevelidot
# ...

# %%
df.drop(columns=['url'], inplace=True)

# %% [markdown]
# ## Created_on feature

# %%
df['created_on'] = pd.to_datetime(df['created_on'], format='%Y-%m-%d %H:%M:%S.%f').dt.strftime('%Y-%m-%d')
df.to_csv(f"{PATH}CleanedData/threads_cleaned.csv", index=False)
df.head()
# Out:
#            id  board_id         creator  creator_id  \
# 0  1098607808       258      randalthor         408
# 1  1208831554        18       sickde666        7360
# 2  1731938282        56    straightdave       13667
# 3  1161153828        56  Krispykremelad        4853
# 4   929896129        56      yungtiller        5524
#
#                                      name  created_on
# 0                             where 2 now  2020-01-09
# 1                                   Login  2020-01-08
# 2                      Withdrawals locked  2019-08-07
# 3  No moderator on my dispute for 8 days?  2019-08-07
# 4                                  No pin  2019-08-07

# %%
df['created_on'].value_counts().sort_index(ascending=False)
# Out:
# created_on
# 2020-04-15        5
# 2020-04-14        2
# 2020-04-13        1
# 2020-02-23      173
# 2020-02-22      119
# 2020-02-21        8
# 2020-01-09    14789
# 2020-01-08    25483
# 2020-01-07    18092
# 2020-01-06      106
# 2020-01-01       63
# 2019-12-31       98
# 2019-12-30        7
# 2019-11-26       66
# 2019-11-11     1022
# 2019-11-06      441
# 2019-11-05     1489
# 2019-11-04       89
# 2019-10-30        4
# 2019-10-29      104
# 2019-10-28       37
# 2019-10-25        9
# 2019-10-24      111
# 2019-08-09       44
# 2019-08-08     4656
# 2019-08-07     1719
# 2019-08-06     6385
# Name: count, dtype: int64

# %%
df['created_on'] = pd.to_datetime(df['created_on'], format='%Y-%m-%d').dt.strftime('%Y-%m')
df.head()
# Out:
#            id  board_id         creator  creator_id  \
# 0  1098607808       258      randalthor         408
# 1  1208831554        18       sickde666        7360
# 2  1731938282        56    straightdave       13667
# 3  1161153828        56  Krispykremelad        4853
# 4   929896129        56      yungtiller        5524
#
#                                      name  \
# 0                             where 2 now
# 1                                   Login
# 2                      Withdrawals locked
# 3  No moderator on my dispute for 8 days?
# 4                                  No pin
#
#                                                  url created_on
# 0  http://dreadditevelidot.onion/post/d0e38d2ba74...    2020-01
# 1  http://dreadditevelidot.onion/post/6ada35da0b3...    2020-01
# 2  http://dreadditevelidot.onion/post/17e952b5b6d...    2019-08
# 3  http://dreadditevelidot.onion/post/9f2dad3183b...    2019-08
# 4  http://dreadditevelidot.onion/post/5f2a5a75a93...    2019-08

# %%
df['created_on'].value_counts().sort_index(ascending=False)
# Out:
# created_on
# 2020-04        8
# 2020-02      300
# 2020-01    58533
# 2019-12      105
# 2019-11     3107
# 2019-10      265
# 2019-08    12804
# Name: count, dtype: int64

# %%
sns.countplot(x='created_on', data=df, orient='h');

# %%
wedges, texts, autotexts = plt.pie(df['created_on'].value_counts(), labels=df['created_on'].value_counts().index, autopct='%1.1f%%', startangle=140, textprops={'fontsize': 10})
plt.legend(wedges, df['created_on'].value_counts().index, title="Created On", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1));

# %%
df.head()
# Out:
#            id  board_id         creator  creator_id  \
# 0  1098607808       258      randalthor         408
# 1  1208831554        18       sickde666        7360
# 2  1731938282        56    straightdave       13667
# 3  1161153828        56  Krispykremelad        4853
# 4   929896129        56      yungtiller        5524
#
#                                      name  \
# 0                             where 2 now
# 1                                   Login
# 2                      Withdrawals locked
# 3  No moderator on my dispute for 8 days?
# 4                                  No pin
#
#                                                  url created_on
# 0  http://dreadditevelidot.onion/post/d0e38d2ba74...    2020-01
# 1  http://dreadditevelidot.onion/post/6ada35da0b3...    2020-01
# 2  http://dreadditevelidot.onion/post/17e952b5b6d...    2019-08
# 3  http://dreadditevelidot.onion/post/9f2dad3183b...    2019-08
# 4  http://dreadditevelidot.onion/post/5f2a5a75a93...    2019-08

# %%
ppu.encode_date_cyclically(df, 'created_on')
# Out:
#                id  board_id          creator  creator_id  \
# 0      1098607808       258       randalthor         408
# 1      1208831554        18        sickde666        7360
# 2      1731938282        56     straightdave       13667
# 3      1161153828        56   Krispykremelad        4853
# 4       929896129        56       yungtiller        5524
# ...           ...       ...              ...         ...
# 75117   566787583       441          fairfax       33131
# 75118   161231059       441           Denode       41474
# 75119    26637282       441           Denode       41474
# 75120   341142936       441  DomesticProduct       42899
# 75121  1821634035       441           Denode       41474
#
#                                                     name  \
# 0                                            where 2 now
# 1                                                  Login
# 2                                     Withdrawals locked
# ...

# %%
df.head()
# Out:
#            id  board_id         creator  creator_id  \
# 0  1098607808       258      randalthor         408
# 1  1208831554        18       sickde666        7360
# 2  1731938282        56    straightdave       13667
# 3  1161153828        56  Krispykremelad        4853
# 4   929896129        56      yungtiller        5524
#
#                                      name  \
# 0                             where 2 now
# 1                                   Login
# 2                      Withdrawals locked
# 3  No moderator on my dispute for 8 days?
# 4                                  No pin
#
#                                                  url created_on  \
# 0  http://dreadditevelidot.onion/post/d0e38d2ba74... 2020-01-01
# 1  http://dreadditevelidot.onion/post/6ada35da0b3... 2020-01-01
# 2  http://dreadditevelidot.onion/post/17e952b5b6d... 2019-08-01
# 3  http://dreadditevelidot.onion/post/9f2dad3183b... 2019-08-01
# 4  http://dreadditevelidot.onion/post/5f2a5a75a93... 2019-08-01
#
# ...

# %%
df['created_on'].value_counts()
# Out:
# created_on
# 2020-01-01    58533
# 2019-08-01    12804
# 2019-11-01     3107
# 2020-02-01      300
# 2019-10-01      265
# 2019-12-01      105
# 2020-04-01        8
# Name: count, dtype: int64

# %% [markdown]
# ## Name feature

# %%
df['name'].value_counts()
# Out:
# name
# MEDICAL GRADE LIQUID KETAMINE AVAILABLE. USA and EUROPE                              54
# Selling paypal logs, bank logs, dumps trk1 trk2  and cvv fullz available instock.    36
# [SnowHeaven®] Colombian Fishscale Cocaine 87% purity, Weed UK->UK                    28
# A+ Weed Vendor                                                                       25
# 500G MDA!/$4000USD! ESCROW! DOMESTIC USA2USA ONLY! WOW!                              23
#                                                                                      ..
# Qualcuno ha comprato da Arsenio ultimamente?                                          1
# TheDarkside Weed - ITA to Europe -                                                    1
# Vendor DMT                                                                            1
# BOOLE, SADOMEN E OMICIDIO SACCHI...                                                   1
# Fresh Database US AK 3K SSN Infos DENODE                                              1
# ...

# %%
ppu.detect_languages(df, 'name')
# Out:
# ...
# Detecting languages: 100%|██████████| 75122/75122 [03:36<00:00, 347.04it/s]
#                id  board_id          creator  creator_id  \
# 0      1098607808       258       randalthor         408
# 1      1208831554        18        sickde666        7360
# 2      1731938282        56     straightdave       13667
# 3      1161153828        56   Krispykremelad        4853
# 4       929896129        56       yungtiller        5524
# ...           ...       ...              ...         ...
# 75117   566787583       441          fairfax       33131
# 75118   161231059       441           Denode       41474
# 75119    26637282       441           Denode       41474
# 75120   341142936       441  DomesticProduct       42899
# 75121  1821634035       441           Denode       41474
#
#                                                     name created_on  \
# 0                                            where 2 now 2020-01-01
# ...

# %%
df['language'].value_counts()
# Out:
# language
# en    61256
# es     3241
# fr     1549
# de     1351
# sq      964
#       ...
# ps        2
# ku        2
# qu        1
# te        1
# az        1
# Name: count, Length: 65, dtype: int64

# %%
df.to_csv(f"{PATH}FeatureEngineeringData/Threads/threads_cleaned.csv", index=False)

# %%
ppu.translate_texts_in_dataframe(df, '../../Datasets/CleanedData/threads_preprocessed_translated.csv', 'name', 'language')
# Out:
# ...
# Translating texts: 100%|██████████| 3866/3866 [36:09<00:00,  1.78it/s]
#                id  board_id          creator  creator_id  \
# 0      1098607808       258       randalthor         408
# 1      1208831554        18        sickde666        7360
# 2      1731938282        56     straightdave       13667
# 3      1161153828        56   Krispykremelad        4853
# 4       929896129        56       yungtiller        5524
# ...           ...       ...              ...         ...
# 75117   566787583       441          fairfax       33131
# 75118   161231059       441           Denode       41474
# 75119    26637282       441           Denode       41474
# 75120   341142936       441  DomesticProduct       42899
# 75121  1821634035       441           Denode       41474
#
#                                                     name  created_on  \
# 0                                            where 2 now  2020-01-01
# ...

# %%
df.drop(columns=['language'], inplace=True)
df.to_csv(f"{PATH}FeatureEngineeringData/Threads/threads_cleaned_translated.csv", index=False)
